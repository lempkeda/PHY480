# %%
# %matplotlib inline
import matplotlib.pylab as plt
data = np.genfromtxt('Final.dat',
                     skip_header=0,
                     skip_footer=1,
                     names=True,
                     dtype=None,
                     delimiter='  ')
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-89abe313b570> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import matplotlib.pylab as plt
# ----> 3 data = np.genfromtxt('Final.dat',
#       4                      skip_header=0,
#       5                      skip_footer=1,
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
plot_data = np.zeros(shape=(len(data),len(data[0])))
iind = -1

for i in data:
    jind = -1
    iind+=1
    #print(i)
    for j in i:
        #print("aaa")
        jind+=1
        plot_data[iind][jind] = j

# %%
def plot_from_file(filename,title):

    data = np.genfromtxt(filename,
                         skip_header=0,
                         skip_footer=1,
                         names=True,
                         dtype=None,
                         delimiter='  ')

    plot_data = np.zeros(shape=(len(data),len(data[0])))
    iind = -1

    for i in data:
        jind = -1
        iind+=1
        #print(i)
        for j in i:
            #print("aaa")
            jind+=1
            plot_data[iind][jind] = j


    plt.plot(plot_data[:,0],plot_data[:,1:])
    plt.legend(('middle','prey','predator'),loc=1)
    plt.xlabel("time")
    plt.ylabel("population")
   # plt.ylim(0,50)
    plt.title(title)

# %%
plot_data[:,0]
# Out:
# array([2.0000e-03, 4.0000e-03, 6.0000e-03, ..., 3.9992e+01, 3.9994e+01,
#        3.9996e+01])

# %%
plt.plot(plot_data[:,0],plot_data[:,1:])
plt.legend(('middle','Prey','Predator','Wage'),loc=1) # middle th = 1.0

# %%
plot_from_file("Final2.dat")    #middle th = 1.0

# %%
plot_from_file("Final3.dat","b = .01")

# %%
plot_from_file("Final3.dat","b = .1")

# %%
plot_from_file("final3.dat","8 random species")

# %%
plot_from_file("finalman.dat","Manual setup. Middle species (2) b = .003 ")
